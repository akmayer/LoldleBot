# %%
s = """<div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Aatrox.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Aatrox </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Darkin </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Manaless </span></div></div></div><div class="square 4 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 15.1px;"><div><div class="" style=""> Runeterra, </div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 animate__animated animate__flipInY square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Ahri.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Ahri </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Vastayan </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Akali.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Akali </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Energy </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Akshan.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Akshan </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2021 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Alistar.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Alistar </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Minotaur </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Amumu.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Amumu </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Undead, </div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Anivia.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Anivia </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Annie.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Annie </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus, </div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Aphelios.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Aphelios </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2019 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Ashe.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Ashe </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Iceborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/AurelionSol.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Aurelion Sol </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Celestial, </div><div class="" style=""> Dragon </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 15.1px;"><div><div class="" style=""> Runeterra, </div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2016 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Azir.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Azir </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God-Warrior </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 animate__animated animate__flipInY square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2014 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Bard.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Bard </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Celestial </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2015 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Belveth.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Bel'Veth </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void-Being </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Manaless </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2022 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Blitzcrank.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Blitzcrank </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Other </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Golem </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Brand.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Brand </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord, </div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Braum.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Braum </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Iceborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2014 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Briar.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Briar </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Golem </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Health costs </span></div></div></div><div class="square 4 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 animate__animated animate__flipInY square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2023 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Caitlyn.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Caitlyn </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Camille.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Camille </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Cyborg, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2016 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Cassiopeia.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Cassiopeia </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus, </div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Chogath.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Cho'Gath </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void-Being </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Corki.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Corki </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bandle City, </div><div class="" style=""> Piltover </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Darius.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Darius </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Diana.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Diana </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Aspect, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/DrMundo.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Dr. Mundo </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Chemically Altered, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Health costs </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Draven.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Draven </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Ekko.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Ekko </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2015 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Elise.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Elise </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee, </div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Evelynn.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Evelynn </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demon, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Ezreal.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Ezreal </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Fiddlesticks.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Fiddlesticks </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Other </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demon, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Fiora.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Fiora </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Fizz.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Fizz </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/MissFortune.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Miss Fortune </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/TwistedFate.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Twisted Fate </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Galio.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Galio </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Golem </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Gangplank.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Gangplank </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Garen.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Garen </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Manaless </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Gnar.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Gnar </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Rage </span></div></div></div><div class="square 4 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee, </div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2014 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Gragas.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Gragas </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Graves.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Graves </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Gwen.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Gwen </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Camavor, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2021 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Renata.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Renata Glasc </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Chemically Altered, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2022 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Hecarim.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Hecarim </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Undead </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Camavor, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Heimerdinger.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Heimerdinger </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Hwei.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Hwei </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2023 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Illaoi.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Illaoi </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2015 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Irelia.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Irelia </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Ivern.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Ivern </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord, </div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2016 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/JarvanIV.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Jarvan IV </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Janna.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Janna </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima, </div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Jax.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Jax </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Unknown </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 15.1px;"><div><div class="small-text" style=""> Icathia, </div><div class="small-text" style=""> Runeterra, </div><div class="small-text" style=""> Shurima </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Jayce.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Jayce </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee, </div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Jhin.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Jhin </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2016 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Jinx.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Jinx </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Chemically Altered, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 animate__animated animate__flipInY square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/KSante.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> K'Sante </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2022 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Kaisa.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kai'Sa </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Void-Being </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima, </div><div class="" style=""> Void </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2018 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Kalista.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kalista </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Undead </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Camavor, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2014 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Karma.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Karma </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Karthus.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Karthus </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Undead </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Kassadin.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kassadin </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Void-Being </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima, </div><div class="" style=""> Void </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Katarina.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Katarina </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Manaless </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Kayle.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kayle </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.35px;"><div><div class="small-text" style=""> Aspect, </div><div class="small-text" style=""> Human, </div><div class="small-text" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee, </div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia, </div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Kayn.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kayn </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.35px;"><div><div class="small-text" style=""> Darkin, </div><div class="small-text" style=""> Human, </div><div class="small-text" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.35px;"><div><div class="smaller-text" style=""> Ionia, </div><div class="smaller-text" style=""> Noxus, </div><div class="smaller-text" style=""> Runeterra, </div><div class="smaller-text" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2017 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Kennen.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kennen </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Energy </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Khazix.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kha'Zix </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void-Being </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Kindred.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kindred </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Other </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2015 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Kled.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kled </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Courage </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2016 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/KogMaw.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Kog'Maw </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void-Being </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/TahmKench.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Tahm Kench </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demon, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 13.75px;"><div><div class="" style=""> Bilgewater, </div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2015 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Leblanc.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> LeBlanc </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/LeeSin.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lee Sin </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Energy </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Leona.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Leona </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Aspect, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Lillia.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lillia </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2020 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Lissandra.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lissandra </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Iceborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Lucian.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lucian </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Lulu.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lulu </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bandle City </div></div></div></div></div><div class="square 6 animate__animated animate__flipInY square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div>"""
s2 = """<div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Leblanc.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> LeBlanc </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/LeeSin.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lee Sin </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Energy </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Leona.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Leona </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Aspect, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Lillia.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lillia </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2020 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Lissandra.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lissandra </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Iceborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Lucian.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lucian </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Lulu.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lulu </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bandle City </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Lux.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Lux </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/DrMundo.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Dr. Mundo </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Chemically Altered, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Health costs </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Malphite.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Malphite </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Golem </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ixtal, </div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Malzahar.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Malzahar </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Void-Being </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima, </div><div class="" style=""> Void </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Maokai.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Maokai </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/MasterYi.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Master Yi </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Milio.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Milio </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ixtal </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2023 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/MissFortune.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Miss Fortune </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Mordekaiser.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Mordekaiser </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Revenant </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Shield </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Morgana.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Morgana </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.35px;"><div><div class="small-text" style=""> Aspect, </div><div class="small-text" style=""> Human, </div><div class="small-text" style=""> Magically Altered </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia, </div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Naafiri.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Naafiri </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Darkin, </div><div class="" style=""> Dog </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2023 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Nami.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Nami </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Vastayan </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 13.75px;"><div><div class="" style=""> Bilgewater, </div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Nasus.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Nasus </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God-Warrior </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Nautilus.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Nautilus </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Revenant </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Neeko.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Neeko </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Vastayan </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ixtal </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2018 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Nidalee.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Nidalee </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee, </div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ixtal </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Nilah.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Nilah </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2022 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Nocturne.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Nocturne </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demon, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Nunu.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Nunu &amp; Willump </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Yeti </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Olaf.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Olaf </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Iceborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Orianna.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Orianna </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Golem </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Ornn.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Ornn </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2017 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Pantheon.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Pantheon </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="small-text" style=""> Middle, </div><div class="small-text" style=""> Support, </div><div class="small-text" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Aspect, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Poppy.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Poppy </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Pyke.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Pyke </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Revenant </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2018 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Qiyana.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Qiyana </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ixtal </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2019 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Quinn.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Quinn </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Rakan.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Rakan </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Vastayan </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2017 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Rammus.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Rammus </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God-Warrior </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/RekSai.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Rek'Sai </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void-Being </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Rage </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima, </div><div class="" style=""> Void </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2014 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Rell.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Rell </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="small-text" style=""> Human, </div><div class="small-text" style=""> Magically Altered, </div><div class="small-text" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2020 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Renata.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Renata Glasc </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Chemically Altered, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2022 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Renekton.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Renekton </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God-Warrior </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Fury </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Rengar.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Rengar </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Vastayan </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Ferocity </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ixtal, </div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Riven.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Riven </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Manaless </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia, </div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Rumble.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Rumble </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Heat </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bandle City </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Ryze.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Ryze </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/AurelionSol.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Aurelion Sol </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Celestial, </div><div class="" style=""> Dragon </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 15.1px;"><div><div class="" style=""> Runeterra, </div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2016 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Samira.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Samira </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus, </div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2020 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Sejuani.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Sejuani </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Iceborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Senna.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Senna </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Undead </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2019 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Seraphine.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Seraphine </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover, </div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2020 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Sett.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Sett </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Vastayan </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Grit </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2020 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Shaco.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Shaco </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Shen.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Shen </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Energy </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Shyvana.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Shyvana </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Dragon, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Fury </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Singed.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Singed </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Chemically Altered, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover, </div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Sion.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Sion </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Revenant </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Sivir.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Sivir </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Skarner.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Skarner </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Brackern </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Sona.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Sona </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia, </div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Soraka.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Soraka </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Celestial </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia, </div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Swain.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Swain </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Sylas.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Sylas </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia, </div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2019 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Syndra.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Syndra </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/TahmKench.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Tahm Kench </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demon, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 13.75px;"><div><div class="" style=""> Bilgewater, </div><div class="" style=""> Runeterra </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2015 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Taliyah.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Taliyah </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2016 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Talon.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Talon </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Taric.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Taric </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Aspect, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia, </div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Teemo.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Teemo </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bandle City </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Thresh.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Thresh </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Undead </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Tristana.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Tristana </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bandle City </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Trundle.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Trundle </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Iceborn, </div><div class="" style=""> Troll </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Tryndamere.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Tryndamere </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Fury </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/TwistedFate.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Twisted Fate </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.5px;"><div><div class="" style=""> Bilgewater </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Twitch.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Twitch </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Chemically Altered, </div><div class="" style=""> Rat </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Udyr.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Udyr </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.8px;"><div><div class="" style=""> Human, </div><div class="" style=""> Spiritualist </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord, </div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Urgot.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Urgot </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="small-text" style=""> Chemically Altered, </div><div class="small-text" style=""> Cyborg, </div><div class="small-text" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Noxus, </div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Varus.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Varus </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom, </div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Darkin, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 15.1px;"><div><div class="small-text" style=""> Ionia, </div><div class="small-text" style=""> Runeterra, </div><div class="small-text" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Vayne.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Vayne </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Demacia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Veigar.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Veigar </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 12.85px;"><div><div class="small-text" style=""> Bandle City, </div><div class="small-text" style=""> Runeterra, </div><div class="small-text" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Velkoz.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Vel'Koz </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void-Being </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Void </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2014 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Vex.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Vex </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.35px;"><div><div class="" style=""> Bandle City, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2021 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Vi.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Vi </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover, </div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Viego.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Viego </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Undead </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Manaless </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Camavor, </div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2021 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Viktor.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Viktor </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Cyborg, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Piltover, </div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Vladimir.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Vladimir </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><span style=""> Bloodthirst </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.35px;"><div><div class="small-text" style=""> Camavor, </div><div class="small-text" style=""> Noxus, </div><div class="small-text" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Volibear.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Volibear </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God, </div><div class="" style=""> Spirit </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Freljord </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Warwick.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Warwick </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="small-text" style=""> Chemically Altered, </div><div class="small-text" style=""> Cyborg, </div><div class="small-text" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/MonkeyKing.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Wukong </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Vastayan </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Xayah.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Xayah </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Vastayan </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2017 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Xerath.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Xerath </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> God-Warrior </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shurima </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/XinZhao.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Xin Zhao </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="small-text" style=""> Demacia, </div><div class="small-text" style=""> Ionia, </div><div class="small-text" style=""> Noxus </div></div></div></div></div><div class="square 6 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2010 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Yasuo.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Yasuo </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Flow </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Yone.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Yone </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-partial" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle, </div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Manaless </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2020 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Yorick.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Yorick </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Top </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Shadow Isles </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2011 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Yuumi.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Yuumi </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Cat, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bandle City </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2019 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Zac.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Zac </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Jungle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Golem </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Health costs </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2013 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Zed.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Zed </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magically Altered </div></div></div></div></div><div class="square 3 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Energy </span></div></div></div><div class="square 4 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Melee </div></div></div></div></div><div class="square 5 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ionia </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Zeri.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Zeri </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2022 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Ziggs.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Ziggs </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Bottom, </div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Yordle </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Zaun </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Zilean.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Zilean </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Male </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 14.2px;"><div><div class="" style=""> Human, </div><div class="" style=""> Magicborn </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 15.1px;"><div><div class="small-text" style=""> Icathia, </div><div class="small-text" style=""> Runeterra, </div><div class="small-text" style=""> Shurima </div></div></div></div></div><div class="square 6 square-superior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2009 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Zoe.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Zoe </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Middle </div></div></div></div></div><div class="square 2 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Aspect, </div><div class="" style=""> Human </div></div></div></div></div><div class="square 3 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Targon </div></div></div></div></div><div class="square 6 square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2017 </span></div></div></div></div></div><div class="classic-answer"><div class="square-container"><div class="square" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="display: flex;"><img src="https://ddragon.leagueoflegends.com/cdn/14.4.1/img/champion/Zyra.png" width="100%" height="100%"><div class="champion-icon-name" style="display: none;"> Zyra </div></div></div></div><div class="square 0 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Female </span></div></div></div><div class="square 1 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Support </div></div></div></div></div><div class="square 2 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Unknown </div></div></div></div></div><div class="square 3 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> Mana </span></div></div></div><div class="square 4 animate__animated animate__flipInY square-good" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ranged </div></div></div></div></div><div class="square 5 animate__animated animate__flipInY square-bad" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><div><div class="" style=""> Ixtal </div></div></div></div></div><div class="square 6 animate__animated animate__flipInY square-inferior" style="flex-basis: calc(12.5% - 4px);"><div class="square-content"><div style="font-size: 16px;"><span style=""> 2012 </span></div></div></div></div></div>"""

soupString = s + s2

# %%
from bs4 import BeautifulSoup
class Champion():
    def __init__(self, name, gender, positions, species, resource, rangeType, regions, releaseYear):
        self.name = name
        self.gender = gender
        self.positions = positions
        self.species = species
        self.resource = resource
        self.rangeType = rangeType
        self.regions = regions
        self.releaseYear = releaseYear
        self.attributes = [gender, positions, species, resource, rangeType, regions, releaseYear]
    
    def compareToAnswer(self, answerChamp):
        returnMatching = []
        for index, attribute in enumerate(self.attributes[:-1]):
            otherAttribute = answerChamp.attributes[index]
            if (attribute == otherAttribute):
                returnMatching.append("g")
                continue
                
            attributeIntersection = attribute.intersection(otherAttribute)
            
            if len(attributeIntersection) != 0:
                returnMatching.append("y")
            else:
                returnMatching.append("r")
        
        if self.releaseYear < answerChamp.releaseYear:
            returnMatching.append("h")
        elif self.releaseYear > answerChamp.releaseYear:
            returnMatching.append("l")
        else:
            returnMatching.append("g")
        return tuple(returnMatching)
    
    def __str__(self):
        return f"""{self.name}
    Gender:\t{self.gender}
    Positions:\t{self.positions}
    Species:\t{self.species}
    Resource:\t{self.resource}
    Range Type:\t{self.rangeType}
    Regions:\t{self.regions}
    Release:\t{self.releaseYear}
    """
    
    def __repr__(self):
        return self.name
    
def cleanStr(squareContent):
    return set([word.strip() for word in squareContent.text.split(",")])
        
def classicAnswerToSquareContentResultSet(classicAnswerSoup):
    return classicAnswerSoup.find("div").find_all("div", "square-content")

def parseSquareContentResultSet(squareContentSoup):
    name = squareContentSoup[0].text.strip()
    gender = cleanStr(squareContentSoup[1])
    positions = cleanStr(squareContentSoup[2])
    species = cleanStr(squareContentSoup[3])
    resource = cleanStr(squareContentSoup[4])
    rangeType = cleanStr(squareContentSoup[5])
    regions = cleanStr(squareContentSoup[6])
    releaseYear = int(squareContentSoup[7].text.strip())
    return Champion(name, gender, positions, species, resource, rangeType, regions, releaseYear)

soup = BeautifulSoup(soupString)

allClassicAnswerSoups = soup.find_all("div", "classic-answer")

championData = [parseSquareContentResultSet(classicAnswerToSquareContentResultSet(classicAnswerSoup)) for classicAnswerSoup in allClassicAnswerSoups]
championData = {champion.name : champion for champion in championData}

# %%
#Dict where pairwiseMatchLookup[queryAnswer][trueNaswer] gives the ["red", "green", "yellow", "red", ..., "higher"] list
#for if your guess was good or not
pairwiseLookup = {}
for queryChampion in championData.values():
    pairwiseLookup[queryChampion.name] = {}
    for answerChampion in championData.values():
        pairwiseLookup[queryChampion.name][answerChampion.name] = queryChampion.compareToAnswer(answerChampion)
        
fullAnswerPool = set(championData.keys())

# %%
print(championData["Ahri"])
print(championData["Neeko"])
print(pairwiseLookup["Neeko"]["Ahri"])
# Out:
# Ahri
#     Gender:	{'Female'}
#     Positions:	{'Middle'}
#     Species:	{'Vastayan'}
#     Resource:	{'Mana'}
#     Range Type:	{'Ranged'}
#     Regions:	{'Ionia'}
#     Release:	2011
#
# Neeko
#     Gender:	{'Female'}
#     Positions:	{'Support', 'Middle'}
#     Species:	{'Vastayan'}
#     Resource:	{'Mana'}
#     Range Type:	{'Ranged'}
#     Regions:	{'Ixtal'}
#     Release:	2018
#
# ('g', 'y', 'g', 'g', 'g', 'r', 'l')

# %%
import numpy as np
def guessToFilteredAnswer(answerPool, guess):
    possibleOutcomes = pairwiseLookup[guess]
    guessResultToAnswer = {guessResult : set([]) for guessResult in possibleOutcomes.values()}
    for answer, guessResult in possibleOutcomes.items():
        if answer in answerPool:
            guessResultToAnswer[guessResult].add(answer)
    return guessResultToAnswer

def getGuessToCountDict(answerPool, guess):
    possibleOutcomes = pairwiseLookup[guess]
    guessResultToOutsize = {guessResult : 0 for guessResult in possibleOutcomes.values()}
    for answer, guessResult in possibleOutcomes.items():
        if answer in answerPool:
            guessResultToOutsize[guessResult] += 1
    return guessResultToOutsize

def getGuessInTwoMetric(guessToCountResult):
    metric = 0
    for champCount in guessToCountResult.values():
        if champCount == 1:
            metric += 1
    return metric

def getEntropyMetric(answerPool, championName):
    guessToCountResult = getGuessToCountDict(answerPool, championName)
    metric = 0
    totalChampCount = sum(guessToCountResult.values())
    for champCount in guessToCountResult.values():
        if champCount != 0:
            prob = champCount / totalChampCount
            metric -= prob * np.log2(prob)
    return round(metric, 4)
    

def getChampScores(answerPool):
    guessInTwoList = []
    for championName in fullAnswerPool:
        guessToCountResult = getGuessToCountDict(answerPool, championName)
        guessInTwoList.append((championName, getGuessInTwoMetric(guessToCountResult), getEntropyMetric(answerPool, championName), championName in answerPool))
    return sorted(guessInTwoList, key = lambda champ : champ[2], reverse=True)
print('\n'.join([str(x) for x in getChampScores(fullAnswerPool)[:20]]))
print()
print('\n'.join([str(x) for x in getChampScores(fullAnswerPool)[-20:]]))
# Out:
# ('Xin Zhao', 62, 6.1693, True)
# ('Talon', 56, 6.1681, True)
# ('Brand', 46, 6.1513, True)
# ('Riven', 60, 6.107, True)
# ('Cassiopeia', 63, 6.0802, True)
# ('Sona', 52, 6.0213, True)
# ('Varus', 39, 6.0186, True)
# ('Swain', 53, 6.0041, True)
# ('Vayne', 40, 5.996, True)
# ('Syndra', 50, 5.993, True)
# ('Darius', 58, 5.9859, True)
# ('Vi', 44, 5.9802, True)
# ('Akali', 51, 5.967, True)
# ('Viktor', 53, 5.9651, True)
# ('Jarvan IV', 51, 5.965, True)
# ('Graves', 46, 5.9533, True)
# ('Lux', 52, 5.9512, True)
# ('Annie', 41, 5.9469, True)
# ('Karma', 51, 5.9425, True)
# ('Irelia', 49, 5.9167, True)
#
# ('Teemo', 28, 4.618, True)
# ('Neeko', 25, 4.605, True)
# ("Rek'Sai", 23, 4.5995, True)
# ('Vex', 25, 4.5839, True)
# ("Kog'Maw", 20, 4.5618, True)
# ('Zac', 19, 4.5456, True)
# ("Cho'Gath", 23, 4.5214, True)
# ('Xayah', 29, 4.5128, True)
# ('Pyke', 16, 4.4432, True)
# ('Naafiri', 24, 4.4269, True)
# ('Kalista', 18, 4.4059, True)
# ('Twitch', 26, 4.265, True)
# ...

# %%
curPool = fullAnswerPool
suggestedGuesses = getChampScores(curPool)[:5]
while suggestedGuesses[0][1] > 1:
    print(curPool)
    suggestedGuesses = getChampScores(curPool)[:5]
    print(suggestedGuesses)
    guess = input("Champion Guess: ")
    guessResult = input("Champion Guess Result: ")
    guessResult = tuple(guessResult.split(' '))
    curPool = guessToFilteredAnswer(curPool, guess)[guessResult]
# Out:
# {'Gragas', 'Blitzcrank', 'Karma', 'Xayah', 'Sett', 'Nami', 'Thresh', 'Miss Fortune', 'Wukong', 'Heimerdinger', 'Jhin', 'Soraka', 'Janna', 'Malphite', 'Ahri', 'Trundle', 'Kindred', 'Ryze', 'Katarina', 'Twitch', 'Viego', 'Hecarim', 'Sejuani', 'Sylas', 'Viktor', 'Cassiopeia', 'Vladimir', "Bel'Veth", 'Ivern', 'Garen', 'Bard', 'Varus', 'Leona', 'Milio', 'Vex', 'Orianna', "Cho'Gath", 'Shaco', 'Aphelios', 'Ezreal', 'Xerath', 'Ekko', 'Pantheon', 'Amumu', "Rek'Sai", 'Skarner', 'Udyr', 'Yasuo', 'Veigar', 'Xin Zhao', 'Taliyah', 'Yorick', 'Sivir', 'Dr. Mundo', 'Zeri', 'Diana', 'Neeko', 'Rengar', 'Shen', 'Darius', 'Caitlyn', 'Gnar', 'Annie', 'Rakan', 'Zyra', "Vel'Koz", 'Samira', 'Anivia', "Kha'Zix", 'Nidalee', 'Rumble', 'Fiddlesticks', 'Seraphine', 'Camille', "Kai'Sa", 'Pyke', 'Senna', 'Gwen', 'Lee Sin', 'Yone', 'Lulu', 'Kennen', 'Nautilus', 'Sion', 'Alistar', 'Hwei', 'Jax', 'Zed', 'Briar', 'Lux', 'Malzahar', 'Mordekaiser', 'Irelia', 'Jarvan IV', 'Renekton', 'Urgot', 'Jinx', 'Fiora', 'Fizz', 'Tri
# ...

# %%
#Precompute all ways that any guess will slice the set of all things. Idea is that
#Guesses on any subset of the set of all things will be the intersection of
#The slice on all things with that filtered subset

guessToResultSlice = {}

for champion in fullAnswerPool:
    guessToResultSlice[champion] = guessToFilteredAnswer(fullAnswerPool, champion)
    
trueAns = "Mordekaiser"
    
guess1 = "Aatrox"
guess2 = "Teemo"

#Current Way:
curPool = fullAnswerPool
guessResult = pairwiseLookup[guess1][trueAns]
curPool = guessToFilteredAnswer(curPool, guess1)[guessResult]
print(curPool)

guessResult = pairwiseLookup[guess2][trueAns]
curPool = guessToFilteredAnswer(curPool, guess2)[guessResult]
print(curPool)

print()
#New Way:
curPool = fullAnswerPool
guessResult = pairwiseLookup[guess1][trueAns]
curPool = guessToResultSlice[guess1][guessResult].intersection(curPool)
print(curPool)
guessResult = pairwiseLookup[guess2][trueAns]
curPool = guessToResultSlice[guess2][guessResult].intersection(curPool)
print(curPool)
# Out:
# {'Yorick', 'Singed', 'Gangplank', 'Dr. Mundo', 'Sion', 'Mordekaiser', 'Shen', 'Darius', "Cho'Gath", 'Tryndamere'}
# {'Mordekaiser', 'Shen'}
#
# {"Cho'Gath", 'Yorick', 'Singed', 'Gangplank', 'Dr. Mundo', 'Mordekaiser', 'Shen', 'Darius', 'Sion', 'Tryndamere'}
# {'Mordekaiser', 'Shen'}

# %%
from itertools import permutations
from tqdm import tqdm
import heapq

fullAnswerList = sorted(list(fullAnswerPool))

permSize = 2
perm = permutations(fullAnswerList, permSize)

#Dictionary between a permutation and the number of guesses it took to win
permScoreDict = {}

for guessPermutation in tqdm(list(perm)):
    #print("Permutation:", guessPermutation)
    
    permScoreDict[guessPermutation] = [0] * (permSize + 1)
    for trueAnswer in fullAnswerList:
        #print("True Answer:", trueAnswer)
        curPool = fullAnswerPool
        for i, guess in enumerate(guessPermutation):
            if guess == trueAnswer:
                permScoreDict[guessPermutation][i] += 1
                break
            guessResult = pairwiseLookup[guess][trueAnswer]
            curPool = guessToResultSlice[guess][guessResult].intersection(curPool)
            #print(curPool)
            if len(curPool) == 1:
                permScoreDict[guessPermutation][i + 1] += 1
                break
            
        #print(permScoreDict[guessPermutation])
        #print()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 27390/27390 [00:15<00:00, 1747.74it/s]

# %%
import pandas as pd

df = pd.DataFrame()
firstGuess = list(zip(*list(zip(*permScoreDict.items()))[0]))[0]
secondGuess = list(zip(*list(zip(*permScoreDict.items()))[0]))[1]
winInOne = list(zip(*list(zip(*permScoreDict.items()))[1]))[0]
winInTwo = list(zip(*list(zip(*permScoreDict.items()))[1]))[1]
winInThree = list(zip(*list(zip(*permScoreDict.items()))[1]))[2]
df["firstGuess"] = firstGuess
df["secondGuess"] = secondGuess
df["winInOne"] = winInOne
df["winInTwo"] = winInTwo
df["winInThree"] = winInThree
df["winByThree"] = (df["winInOne"] + df["winInTwo"] + df["winInThree"])
df.sort_values(by=["winByThree", "winInTwo"], ascending=[False, False])[:10]
# Out:
#       firstGuess   secondGuess  winInOne  winInTwo  winInThree  winByThree
# 25421   Xin Zhao          Azir         1        62          68         131
# 17666      Riven          Azir         1        60          70         131
# 1921        Azir         Riven         1        34          96         131
# 1968        Azir      Xin Zhao         1        34          96         131
# 17817      Riven        Zilean         1        60          69         130
# 27002     Zilean         Riven         1        47          82         130
# 17702      Riven         Janna         1        60          68         129
# 7861       Janna         Riven         1        23         105         129
# 25420   Xin Zhao  Aurelion Sol         1        62          64         127
# 17782      Riven       Taliyah         1        60          66         127

# %%
def filterByTuple(guessTuple, trueAnswer):
    curPool = fullAnswerPool
    for guess in guessTuple:
        guessResult = pairwiseLookup[guess][trueAnswer]
        curPool = guessToResultSlice[guess][guessResult].intersection(curPool)
    return curPool

df = pd.read_csv("loldleThreePerms.txt")
df["winByThree"] = (df["winInOne"] + df["winInTwo"] + df["winInThree"])
df["winByFour"] = (df["winInOne"] + df["winInTwo"] + df["winInThree"] + df["winInFour"])

# %%
df[(df["winInTwo"] >= 60) & (df["winInThree"] >= 65)].sort_values(["winByThree", "winByFour"], ascending=[False, False])
# Out:
#       guessOne      guessTwo    guessThree  winInOne  winInTwo  winInThree  \
# 94       Riven          Azir     Seraphine         1        60          71
# 112   Xin Zhao          Azir          Gwen         1        62          69
# 128   Xin Zhao          Azir     Seraphine         1        62          69
# 92       Riven          Azir  Renata Glasc         1        60          71
# 118   Xin Zhao          Azir        Maokai         1        62          69
# ...        ...           ...           ...       ...       ...         ...
# 4230     Riven         Braum         Leona         1        60          65
# 4420     Riven        Veigar        Rumble         1        60          65
# 4439     Riven        Veigar         Teemo         1        60          65
# 3955     Riven         Amumu         Nasus         1        60          65
# 4135     Riven  Aurelion Sol           Zoe         1        60          65
#
#       winInFour  winByThree  winByFour
# ...

# %%
multiIndexedDf = df.sort_values(["guessOne", "guessTwo", "guessThree"]).set_index(["guessOne", "guessTwo", "guessThree"])
multiIndexedDf.loc["Talon"]
# Out:
#                      winInOne  winInTwo  winInThree  winInFour  winByThree  \
# guessTwo guessThree
# Aatrox   Ahri               1        55          53         25         109
#          Akali              1        55          52         24         108
#          Akshan             1        55          52         17         108
#          Alistar            1        55          52         30         108
#          Amumu              1        55          53         32         109
# ...                       ...       ...         ...        ...         ...
# Zyra     Zed                1        56          34         27          91
#          Zeri               1        56          35         26          92
#          Ziggs              1        56          34         24          91
#          Zilean             1        56          34         36          91
#          Zoe                1        56          35         27          92
#
#                      winByFour
# ...

# %%
#####################Instead of picking the best 3 universally, after some champ, can you guarantee to get it by the third
startGuess = "Talon"
missedAfterStart = set([])
for trueAnswer in fullAnswerList:
    curPool = fullAnswerPool
    if startGuess == trueAnswer:
        curPool = {trueAnswer}
        continue
    guessResult = pairwiseLookup[startGuess][trueAnswer]
    curPool = guessToResultSlice[startGuess][guessResult].intersection(curPool)
    #print(curPool)
    if len(curPool) == 1:
        continue
    
    if len(curPool) != 1:
        missedAfterTuple.add(tuple(curPool))

for filteredPool in missedAfterTuple:
    print(f"{startGuess} First Guess\nFeedback: {' '.join(pairwiseLookup[startGuess][filteredPool[0]])}\nRemaining Options:{filteredPool}")
    bitsUncertanty = round(np.log2(len(filteredPool)), 4)
    
    bestGuess = None
    decentGuess = None
    for nextGuess in fullAnswerPool:
        entropy = getEntropyMetric(filteredPool, nextGuess)
        if entropy == bitsUncertanty:
            decentGuess = nextGuess
            if nextGuess in filteredPool:
                bestGuess = nextGuess
    if bestGuess != None:
        print("Best Next Guess:", bestGuess)
    elif decentGuess != None:
        print("Decent Next Guess:", decentGuess)
    print()
# Out:
# Talon First Guess
# Feedback: g y y g r r h
# Remaining Options:('Varus', 'Hwei', 'Ivern')
# Best Next Guess: Hwei
#
# Talon First Guess
# Feedback: r y r g g r h
# Remaining Options:('Lillia', 'Naafiri')
# Best Next Guess: Naafiri
#
# Talon First Guess
# Feedback: g y r g g r l
# Remaining Options:('Jax', 'Amumu', 'Trundle', 'Galio', 'Rammus', 'Shaco')
# Best Next Guess: Rammus
#
# Talon First Guess
# Feedback: g r y g r r l
# Remaining Options:('Zilean', 'Ezreal')
# Best Next Guess: Zilean
#
# Talon First Guess
# Feedback: g r y g r r h
# Remaining Options:('Jhin', 'Aphelios', 'Milio')
# Best Next Guess: Aphelios
#
# Talon First Guess
# Feedback: g r y g g r l
# Remaining Options:('Taric', 'Singed')
# Best Next Guess: Taric
#
# Talon First Guess
# Feedback: r y r r g r h
# Remaining Options:("Bel'Veth", "Rek'Sai")
# Best Next Guess: Rek'Sai
#
# Talon First Guess
# Feedback: g y y g r r l
# Remaining Options:('Malzahar', 'Twisted Fate', 'Ryze')
# Best Next Guess: Twisted Fate
#
# ...

# %%
###Simulate games with the following strategy:
def selectEntropyAndTwoStep(answerPool, default=None):
    #First, if there are any champions that will guarantee that you get it in two steps, select that champion
    #Prioritize a guess within the answerPool for a chance of getting it on the next step
    bitsUncertanty = round(np.log2(len(answerPool)), 4)

    bestGuess = None
    bestGuessEntropy = -1
    decentGuess = None
    for nextGuess in fullAnswerPool:
        entropy = getEntropyMetric(answerPool, nextGuess)
        
        if entropy == bitsUncertanty:
            decentGuess = nextGuess
            if nextGuess in answerPool and entropy > bestGuessEntropy:
                bestGuess = nextGuess
                bestGuessEntropy = entropy
    if bestGuess != None:
        return bestGuess
    if decentGuess != None:
        return decentGuess
    
    if default != None:
        return default
    
    
    #If neither works, select the champion with the highest entropy
    championEntropy = [(champion, getEntropyMetric(answerPool, champion)) for champion in answerPool]
    championEntropy = sorted(championEntropy, key= lambda pair : pair[1], reverse=True)
    return championEntropy[0][0]

def selectHighestEntropy(answerPool, default=None):
    if default != None:
        return default
    championEntropy = [(champion, getEntropyMetric(answerPool, champion)) for champion in answerPool]
    championEntropy = sorted(championEntropy, key= lambda pair : pair[1], reverse=True)
    return championEntropy[0][0]


def filterPool(poolPreFilter, guess, trueAns):
    guessResult = pairwiseLookup[guess][trueAns]
    return guessToResultSlice[guess][guessResult].intersection(poolPreFilter)


#Simulate the number of rounds it takes with the following strategy for all the possible games
#Takes in an optional defaultChampionList = [] parameter where it will pass in the first champion
#as the default on the first round, second on second, etc
def simulateAllGames(strategy, defaultChampionList = []):
    numRoundsArr = []
    for trueAnswer in fullAnswerList:
        allGuesses = []
        numRounds = 1
        curPool = fullAnswerPool
        while True:
            if numRounds <= len(defaultChampionList):
                guess = strategy(curPool, defaultChampionList[numRounds - 1])
            else:
                guess = strategy(curPool)
            allGuesses.append(guess)
            if guess == trueAnswer:
                numRoundsArr.append(numRounds)
                break
            curPool = filterPool(curPool, guess, trueAnswer)
            numRounds += 1

    return numRoundsArr

# %%
import numpy as np

championEntropyList = [(champion, getEntropyMetric(fullAnswerPool, champion)) for champion in fullAnswerPool]
championEntropyList = sorted(championEntropyList, key= lambda pair : pair[1], reverse=True)

onlyEntropy = {}
print(f'{"Champion".ljust(25)}{"Avg Rounds".ljust(25)}{"Std Rounds".ljust(25)}{"Found In 2 Rounds".ljust(25)}')

for champion in championEntropyList:
    numRoundsArr = simulateAllGames(selectHighestEntropy, [champion[0]])
    onlyEntropy[champion[0]] = numRoundsArr
    print(f"{str(champion).ljust(25)}{str(np.mean(numRoundsArr)).ljust(25)}{str(np.std(numRoundsArr)).ljust(25)}{str(np.count_nonzero(np.array(numRoundsArr) <= 2)).ljust(25)}")
# Out:
# Champion                 Avg Rounds               Std Rounds               Found In 2 Rounds
# ('Xin Zhao', 6.1693)     2.4578313253012047       0.5553942444152341       93
# ('Talon', 6.1681)        2.463855421686747        0.5337023025730826       90
# ('Brand', 6.1513)        2.5060240963855422       0.5781877373832206       87
# ('Riven', 6.107)         2.4759036144578315       0.5564713182718629       90
# ('Cassiopeia', 6.0802)   2.463855421686747        0.555818795394667        92
# ('Sona', 6.0213)         2.5180722891566263       0.57793662434754         85
# ('Varus', 6.0186)        2.5120481927710845       0.5234035026565255       81
# ('Swain', 6.0041)        2.5060240963855422       0.5569602087386131       85
# ('Vayne', 5.996)         2.5421686746987953       0.5553942444152342       79
# ('Syndra', 5.993)        2.5120481927710845       0.578093582777513        86
# ('Darius', 5.9859)       2.5120481927710845       0.578093582777513        86
# ...
